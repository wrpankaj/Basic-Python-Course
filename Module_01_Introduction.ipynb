# %% [markdown]
# # 📘 Module 01 – Introduction to Python
#
# ---
#
# ## 🔗 Open in Google Colab
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](INSERT_YOUR_GITHUB_LINK_HERE)
#
# ---
#
# # 🐍 What is Python?
# Python is a high-level, beginner-friendly programming language used worldwide for:
# - Machine Learning
# - Data Science
# - Automation & Scripting
# - Web Development
# - Scientific Research
#
# Python reads like English, making it the perfect first language for beginners.
#
# ---
#
# # ⭐ Features of Python
# ✔ Easy to learn and write
# ✔ Dynamically typed
# ✔ Huge standard library
# ✔ Cross-platform
# ✔ Supports multiple programming paradigms
#
# ---
#
# # 🖥️ First Program in Python
# The `print()` function displays text on the screen.
#
# ### ▶️ Example

# %%
print("Hello, Python!")
print("Welcome to Module 01 – Introduction!")

# %% [markdown]
# ---
# # ✍️ Practice Task 1
# Write a program that prints your **name**, **branch**, and **college**.
#
# ### 💡 Hint: Use `print()` multiple times.

# %%
# Write your answer here

# %% [markdown]
# ---
# # 📥 Input from User
# The `input()` function is used to take values from the user.
#
# ### ▶️ Example:

# %%
name = input("Enter your name: ")
print("Welcome,", name)

# %% [markdown]
# ---
# # ✍️ Practice Task 2
# Ask the user for:
# - Their favourite subject
# - Their favourite programming language
#
# Then print a combined message.

# %%
# Write your answer here

# %% [markdown]
# ---
# # 🧪 Mini Quiz (5 Questions)
#
# ### **1. Python is a ______ typed language.**
# - A. Statically
# - B. Dynamically
# - C. Weakly
# - D. Strongly
# **Correct answer: B**
#
# ### **2. Which function displays output in Python?**
# ✔ `print()`
#
# ### **3. What is the extension of Python files?**
# ✔ `.py`
#
# ### **4. Who invented Python?**
# ✔ Guido van Rossum
#
# ### **5. Which company uses Python?**
# ✔ Google
# ✔ NASA
# ✔ Netflix
# ✔ All of the above

# %% [markdown]
# ---
# # 🎯 Summary
# In this module, you learned:
# - What Python is
# - Where Python is used
# - How to write first program
# - How to take user input
#
# You are now ready for **Module 02 – Variables & Data Types**!
